# %%
from IPython.display import display, Markdown, Latex
# If you particularly want to display maths, this is more direct:
# display(Latex('\phi'))

variables = {
    "title" : "Summary of book Mindfulness voor dummies",
    "inception_date" : "2022-01-15",
    "target_audience" : "People interested in mindfulness",
    "licence" : "[CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/)",
    "inspiration" : "Mindfulness voor dummies",
    "location_original_file" : "",
    "status" : "concept",
    "version" : "2022-02-15T10:33",
}

title = "# " + variables["title"] + "\n\n"

details = "* Title: " + variables["title"] + "\n" + \
"* Inception date: " + variables["inception_date"] + "\n" + \
"* Target audience" + variables["target_audience"] + "\n" + \
"* License: " + variables["licence"] + "\n" + \
"* Inspiration: " + variables["inspiration"] + "\n" + \
"* Location original file: " + variables["location_original_file"] + "\n" + \
"* Status: " + variables["status"] + "\n" + \
"* Version: " + variables["version"] + "2022-02-16T14:47" + "\n"

introduction = """
"""

# %%
body_1 = """
# Reference sheet

* nieuwschierigheid
* acceptatie
* vriendelijkheid
* laten gaan
* zonder oordeel
* zonder inspanning
* geduld
* vertrouwen
* geest van de beginner

# Drie pijlers van mindfulness (IHA)

1. Intentie
1. Houding
1. Aandacht

# Opmerkzaam zijn van je gevoelens bij moeilijke gevallen met de RAIN-methode

1. Realiseer
1. Accpeteer
1. Interesse
1. Non-identificatie

# Sati (Oud Hindustaans woord dat):

1. Bewustzijn
1. Aandacht
1. Herinneren

# Verdere ontleding van Sati:

1. Opmerkzaamheid
1. Dit moment
1. Zonder reactie
1. Zonder oordeel
1. Openhartig

"""

# %%
body_2 = """
"""

body_3 = """
"""

conclusion = """
"""

discussion = """
"""

references = """
"""

essay = title + details + introduction + body_1 + body_2 + body_3 + conclusion + discussion + references
#print(essay)
display(Markdown(essay))
# Out:
# # Summary of book Mindfulness voor dummies
#
# * Title: Summary of book Mindfulness voor dummies
# * Inception date: 2022-01-15
# * Target audiencePeople interested in mindfulness
# * License: [CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/)
# * Inspiration: Mindfulness voor dummies
# * Location original file:
# * Status: concept
# * Version: 2022-02-15T10:332022-02-16T14:47
#
#
# # Reference sheet
#
# * nieuwschierigheid
# * acceptatie
# * vriendelijkheid
# * laten gaan
# * zonder oordeel
# * zonder inspanning
# * geduld
# * vertrouwen
# * geest van de beginner
#
# # Drie pijlers van mindfulness (HIN)
#
# 1. Houding
# 1. Intentie
# 1. Aandacht
#
# # Opmerkzaam zijn van je gevoelens bij moeilijke gevallen met de RAIN-methode
#
# 1. Realiseer
# 1. Accpeteer
# 1. Interesse
# 1. Non-identificatie

# %%
# Out:
# # Summary of book Mindfulness voor dummies
# * Title: Summary of book Mindfulness voor dummies
# * Inception date: 2022-01-15
# * Target audiencePeople interested in mindfulness
# * License: [CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/)
# * Inspiration: Mindfulness voor dummies
# * Location original file:
# * Status: concept
# * Version: 2022-02-15T10:332022-02-15T10:33
#
#
# # Reference sheet
#
# * nieuwschierigheid
# * acceptatie
# * vriendelijkheid
# * laten gaan
# * zonder oordeel
# * zonder inspanning
# * geduld
# * vertrouwen
# * geest van de beginner
#
# # Drie pijlers van mindfulness (HIN)
#
# 1. Houding
# 1. Intentie
# 1. Aandacht
#
# # Opmerkzaam zijn van je gevoelens met de RAIN-methode
#
# 1. Realiseer
# 1. Accpeteer
# 1. Interesse
# 1. Non-identificatie
# # Summary of book Mindfulness voor dummies
# * Title: Summary of book Mindfulness voor dummies
# * Inception date: 2022-01-15
# * Target audiencePeople interested in mindfulness
# * License: [CC BY-SA 4.0](https://creativecommons.org/licenses/by-sa/4.0/)
# * Inspiration: Mindfulness voor dummies
# * Location original file:
# * Status: concept
# * Version: 2022-02-15T10:332022-02-15T10:33
#
#
# # Reference sheet
#
# * nieuwschierigheid
# * acceptatie
# * vriendelijkheid
# * laten gaan
# * zonder oordeel
# * zonder inspanning
# * geduld
# * vertrouwen
# * geest van de beginner
#
# # Drie pijlers van mindfulness (HIN)
#
# 1. Houding
# 1. Intentie
# 1. Aandacht
#
# # Opmerkzaam zijn van je gevoelens met de RAIN-methode
#
# 1. Realiseer
# 1. Accpeteer
# 1. Interesse
# 1. Non-identificatie
