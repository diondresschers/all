# %%
import random

total_students = 532

counter = total_students
times = int((total_students / 13)+1)
tutor_group = []

for times in range (1, times+1, 1):
    for number in range (1, 14, 1):
        tutor_group.append(number)
        #print(number)
        
shuffled_tutor_group = random.sample(tutor_group, len(tutor_group))

for group in shuffled_tutor_group:
    print(group)

region_preference = [
    [
        "Africa (Central)",
        "Africa (East)",
        "Africa (North)",
        "Africa (South)",
        "Africa (West)",
    ],
    [
        "America (Middle)",
        "America (North)",
        "America (South)",
    ],
    [
        "Asia (Central)",
        "Asia (Eastern)",
        "Asia (Nothern)",
        "Asia (South-Eastern)",
        "Asia (Southern)",
        "Asia (Western)",
    ],
    [
        "Australia",
    ],
    [
        "Europe (Eastern)",
        "Europe (Nothern Europe)",
        "Europe (Southern)",
        "Europe (Western)",
    ]
]
# Out:
# 13
# 3
# 9
# 3
# 10
# 12
# 13
# 11
# 11
# 3
# 8
# 5
# 5
# 5
# 6
# 3
# 5
# 5
# 2
# 1
# 12
# 5
# 6
# 10
# 12
# 4
# 3
# 3
# 9
# 10
# 11
# 3
# 2
# 9
# 8
# 7
# 7
# 9
# 8
# 1
# 5
# 13
# 7
# 5
# 8
# 11
# 9
# 10
# 8
# 12
# 3
# 4
# 6
# 11
# 5
# 12
# 3
# 7
# 2
# 8
# 10
# 11
# 3
# 4
# 7
# 1
# 1
# 9
# 13
# 6
# 13
# 12
# 3
# 13
# 6
# 4
# 4
# 2
# 3
# 6
# 9
# 9
# 7
# 6
# 8
# 11
# 6
# 13
# 9
# 5
# 9
# 8
# 13
# 11
# 12
# 8
# 12
# 10
# 2
# 13
# 6
# 13
# 13
# 9
# 9
# 5
# 7
# 2
# 3
# 8
# 8
# 9
# 5
# 3
# 7
# 2
# 1
# 8
# 2
# 3
# 2
# 4
# 11
# 4
# 10
# 10
# 8
# 5
# 2
# 11
# 4
# 7
# 13
# 10
# 2
# 4
# 9
# 11
# 6
# 11
# 12
# 9
# 2
# 4
# 11
# 7
# 11
# 8
# 8
# 10
# 7
# 2
# 7
# 4
# 9
# 5
# 5
# 8
# 3
# 4
# 2
# 6
# 11
# 2
# 6
# 1
# 13
# 3
# 8
# 12
# 6
# 1
# 2
# 3
# 12
# 1
# 9
# 3
# 12
# 9
# 3
# 10
# 12
# 5
# 9
# 6
# 9
# 1
# 11
# 2
# 10
# 13
# 9
# 2
# 12
# 3
# 1
# 8
# 11
# 4
# 8
# 1
# 1
# 4
# 4
# 6
# 10
# 1
# 4
# 9
# 3
# 4
# 3
# 12
# 10
# 6
# 5
# 10
# 7
# 6
# 9
# 13
# 3
# 4
# 12
# 4
# 13
# 6
# 7
# 11
# 13
# 5
# 6
# ...

# %%
def generate_list(region_preference):
    pref = [0,1,2,3,4]
    choice_continent = pref
    temp_cont = []
    pref_cont = []

    for times in range (1, 4, 1):
        item = random.choice(choice_continent)
        temp_cont.append(item)
        #print(item)
        choice_continent.remove(item)
        #print(temp_cont)

    string = "" 
    for item in temp_cont:
        location = random.choice(region_preference[item])
        string += location + ", "
    print(string)

for times in range(1, 533, 1):
    generate_list(region_preference)
# Out:
# Europe (Southern), Africa (West), Australia,
# Africa (Central), Australia, Asia (Central),
# Australia, America (Middle), Asia (Western),
# Africa (Central), Asia (Central), Australia,
# America (Middle), Australia, Europe (Southern),
# Australia, America (Middle), Europe (Nothern Europe),
# Asia (South-Eastern), Europe (Eastern), Australia,
# Africa (West), America (Middle), Australia,
# Europe (Nothern Europe), Africa (Central), America (Middle),
# Africa (West), Australia, Europe (Western),
# America (South), Asia (Western), Europe (Western),
# America (South), Australia, Africa (South),
# America (Middle), Africa (East), Australia,
# Asia (Nothern), America (North), Africa (Central),
# Asia (South-Eastern), Australia, Africa (East),
# Australia, Asia (Western), America (South),
# Africa (Central), Asia (Southern), Australia,
# Africa (North), Australia, Asia (South-Eastern),
# Asia (Eastern), America (North), Europe (Western),
# America (Middle), Africa (Central), Australia,
# ...

# %%
temp = """
* Africa (Central)
* Africa (East)
* Africa (North)
* Africa (South)
* Africa (West)
* America (Middle)
* America (North)
* America (South)
* Asia (Central)
* Asia (Eastern)
* Asia (Nothern)
* Asia (South-East Asia)
* Asia (Southern)
* Asia (Western Asia)
* Australia
* Europe (Eastern)
* Europe (Nothern Europe)
* Europe (Southern)
* Europe (Western)
"""

# %%
gender = ['Man','Man','Man','Man','Man','Woman','Woman','Woman','Woman','Woman','Non-binary','Prefer not to say']

for times in range(1, 533):
          print(random.choice(gender))
# Out:
# Woman
# Man
# Man
# Non-binary
# Man
# Man
# Man
# Man
# Man
# Man
# Man
# Non-binary
# Man
# Woman
# Man
# Woman
# Man
# Man
# Man
# Woman
# Woman
# Prefer not to say
# Woman
# Man
# Non-binary
# Man
# Woman
# Man
# Man
# Woman
# Woman
# Woman
# Prefer not to say
# Woman
# Man
# Man
# Man
# Prefer not to say
# Woman
# Prefer not to say
# Man
# Non-binary
# Woman
# Man
# Woman
# Woman
# Man
# Non-binary
# Woman
# Man
# Non-binary
# Man
# Man
# Prefer not to say
# Prefer not to say
# Man
# Non-binary
# Woman
# Man
# Man
# Prefer not to say
# Woman
# Man
# Man
# Man
# Man
# Man
# Woman
# Woman
# Woman
# Man
# Non-binary
# Non-binary
# Woman
# Prefer not to say
# Woman
# Man
# Woman
# Woman
# Woman
# Man
# Woman
# Prefer not to say
# Man
# Man
# Woman
# Woman
# Woman
# Man
# Woman
# Prefer not to say
# Man
# Woman
# Man
# Non-binary
# Man
# Man
# Man
# Woman
# Prefer not to say
# Woman
# Woman
# Man
# Man
# Non-binary
# Man
# Man
# Man
# Man
# Man
# Woman
# Man
# Woman
# Woman
# ...

# %%
religion = [
    "Atheist/Secular/Nonreligous/Agnostic",
    "Atheist/Secular/Nonreligous/Agnostic",
    "Atheist/Secular/Nonreligous/Agnostic",
    "Atheist/Secular/Nonreligous/Agnostic",
    "African traditional religions",
    "Buddism",
    "Christianity",
    "Christianity",
    "Christianity",
    "Christianity",
    "Christianity",
    "Christianity",
    "Ethnic religion",
    "Hinduism",
    "Hinduism",
    "Islam",
    "Islam",
    "Islam",
    "Islam",
    "Judaism",
    "Sikhism",
    "Spiritism",
    "Prefer not to say",
    "Prefer not to say",
    "Prefer not to say",
    "Prefer not to say",
    "Other",
    "Other",
    "Other",
    "Other",    
]

for times in range(1, 533):
          print(random.choice(religion))
# Out:
# Other
# Prefer not to say
# Prefer not to say
# Christianity
# Other
# Spiritism
# Atheist/Secular/Nonreligous/Agnostic
# Christianity
# Hinduism
# Spiritism
# Christianity
# Christianity
# Prefer not to say
# Christianity
# Christianity
# Prefer not to say
# Christianity
# Prefer not to say
# Other
# Christianity
# Christianity
# Prefer not to say
# Atheist/Secular/Nonreligous/Agnostic
# Islam
# Prefer not to say
# Judaism
# Christianity
# Ethnic religion
# Prefer not to say
# Atheist/Secular/Nonreligous/Agnostic
# Atheist/Secular/Nonreligous/Agnostic
# Christianity
# Prefer not to say
# Other
# Christianity
# Prefer not to say
# Atheist/Secular/Nonreligous/Agnostic
# Other
# Other
# Christianity
# Buddism
# Islam
# Christianity
# Judaism
# Atheist/Secular/Nonreligous/Agnostic
# Hinduism
# Atheist/Secular/Nonreligous/Agnostic
# Judaism
# Atheist/Secular/Nonreligous/Agnostic
# Judaism
# Ethnic religion
# Other
# Islam
# Christianity
# Atheist/Secular/Nonreligous/Agnostic
# ...

# %%
country = [
    "CN",
    "CN",
    "CN",
    "IN",
    "IN",
    "IN",
    "US",
    "US",
    "US",
    "ES",
    "ES",
    "ES",
    "BE",
    "BE",
    "BE",
    "FR",
    "FR",
    "FR",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "NL",
    "BR",
    "NI",
    "RU",
    "JP",
    "TR",
    "PK",
    "NG",
]

for times in range(1, 533):
          print(random.choice(country))
# Out:
# NL
# NL
# CN
# NG
# NL
# NG
# IN
# NL
# NL
# CN
# IN
# IN
# IN
# NL
# US
# NL
# IN
# PK
# PK
# US
# NL
# NL
# FR
# NL
# NL
# NL
# NL
# JP
# FR
# PK
# NL
# NL
# TR
# US
# NL
# FR
# PK
# NL
# NL
# NL
# TR
# CN
# NL
# NL
# NL
# FR
# ES
# JP
# NL
# NL
# NG
# NL
# NL
# NL
# NL
# PK
# NL
# ES
# NL
# TR
# NL
# BE
# BE
# RU
# FR
# NL
# NL
# FR
# NL
# NL
# BR
# US
# US
# CN
# BE
# NL
# NL
# JP
# ES
# NL
# NL
# NL
# RU
# FR
# NL
# CN
# NG
# NG
# NL
# BE
# NG
# NG
# NL
# NG
# CN
# NL
# IN
# TR
# NL
# FR
# NL
# ES
# IN
# NL
# NL
# NL
# RU
# IN
# NL
# JP
# PK
# CN
# TR
# US
# NL
# US
# NL
# US
# FR
# ES
# FR
# BE
# US
# NL
# BE
# NL
# NG
# ES
# CN
# NI
# CN
# BE
# BR
# ES
# IN
# IN
# FR
# NL
# ES
# ES
# IN
# NL
# NL
# BR
# NL
# NL
# FR
# IN
# NL
# RU
# NL
# NL
# NL
# NL
# BR
# US
# NL
# NL
# NL
# TR
# NI
# US
# US
# IN
# NL
# BR
# US
# NL
# IN
# IN
# FR
# NL
# NL
# CN
# NL
# BE
# CN
# NL
# JP
# NL
# IN
# FR
# NL
# PK
# IN
# NL
# NL
# NL
# NL
# JP
# FR
# NL
# IN
# CN
# NL
# NL
# RU
# FR
# NL
# NL
# ...
